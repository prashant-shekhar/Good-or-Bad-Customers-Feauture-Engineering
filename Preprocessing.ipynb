# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("assignment.csv")

# %%
df
# Out:
#         UID Good_Bad CUSTOMER_PROFILE_CODE   LOCATIONNAME  \
# 0         1      Bad               PROF270        MADURAI
# 1         2     Good               PROF218        KOLKATA
# 2         3     Good               PROF305         NAGPUR
# 3         4     Good               PROF356      AHMEDABAD
# 4         5      Bad               PROF300         NAGPUR
# ...     ...      ...                   ...            ...
# 9995   9996      Bad               PROF245        BIKANER
# 9996   9997      Bad               PROF096  VISAKHAPATNAM
# 9997   9998     Good               PROF358         ORISSA
# 9998   9999      Bad               PROF372         SALEM
# 9999  10000     Good               PROF207   TIRUNELVELI
#
#                                          VEHICLEMODEL  ASSETCOST  LOANAMOUNT  \
# 0                      HONDA CITY 1.5 GXI PETROL 2008   900000.0    350000.0
# 1                MARUTI SUZUKI EECO 7 STR PETROL 2011   400000.0    125250.0
# ...

# %% [markdown]
# #                                             Data Preprocessing

# %%
df.describe()
# Out:
#                UID     ASSETCOST    LOANAMOUNT            EMI       TENURE  \
# count  10000.00000  9.855000e+03  9.855000e+03    9855.000000  9855.000000
# mean    5000.50000  5.287254e+05  3.870046e+05   12234.161542    45.119432
# std     2886.89568  3.183957e+05  2.386860e+05    6718.607922    12.179016
# min        1.00000  0.000000e+00  5.000000e+04    1402.000000    12.000000
# 25%     2500.75000  3.000000e+05  2.241250e+05    7750.000000    36.000000
# 50%     5000.50000  4.750000e+05  3.500000e+05   11114.000000    48.000000
# 75%     7500.25000  6.500000e+05  5.000000e+05   14918.000000    60.000000
# max    10000.00000  7.200000e+06  3.512750e+06  103000.000000    60.000000
#
#        NOOFYEARSINSAMECITY  RESIDENCESTABILITY  RESIDENCELOCALITY  \
# count          9758.000000         9781.000000        9778.000000
# mean             26.650618           78.625360           3.053385
# std              14.088494         4424.230301           0.515896
# ...

# %%
df.shape
# Out:
# (10000, 49)

# %% [markdown]
# ### This dataset has 10000 row with 49 features

# %%
df.isnull().sum()
# Out:
# UID                             0
# Good_Bad                        0
# CUSTOMER_PROFILE_CODE           0
# LOCATIONNAME                  128
# VEHICLEMODEL                  147
# ASSETCOST                     145
# LOANAMOUNT                    145
# EMI                           145
# TENURE                        145
# ADDRESSCONFIRMED              145
# DESIGNATION                   220
# RESIDENCETYPE                 242
# NOOFYEARSINSAMECITY           242
# RESIDENCESTABILITY            219
# RESIDENCELOCALITY             222
# BUSINESSCATEGORY              223
# BUSINESSMARGINGROSS           119
# INCOMEEMPLOYMENT              148
# STABILITYINBUSINESS           112
# STABILITYCONFIRMED            107
# STABILTIYCONFIRMEDTHRU       1800
# ISFAMILYINVOLVED              110
# OFFICETYPE                    224
# MONTHLYTURNOVER               109
# STOCKVALUEINHAND              109
# BUSINESSMARGINNET             113
# NOOFEMPLOYEES                 126
# ...

# %% [markdown]
# ### As ASSETREGMONTH , LANDOWNERSHIP , IRRIGATIONSOURCE, CROPSCULTIVATED has no values so it has no impact on dataset. Better Remove it.

# %%
df = df.drop(['LANDOWNERSHIP', 'IRRIGATIONSOURCE', 'CROPSCULTIVATED', 'ASSETREGMONTH'], axis = 1)
df.head()
# Out:
#    UID Good_Bad CUSTOMER_PROFILE_CODE LOCATIONNAME  \
# 0    1      Bad               PROF270      MADURAI
# 1    2     Good               PROF218      KOLKATA
# 2    3     Good               PROF305       NAGPUR
# 3    4     Good               PROF356    AHMEDABAD
# 4    5      Bad               PROF300       NAGPUR
#
#                                       VEHICLEMODEL  ASSETCOST  LOANAMOUNT  \
# 0                   HONDA CITY 1.5 GXI PETROL 2008   900000.0    350000.0
# 1             MARUTI SUZUKI EECO 7 STR PETROL 2011   400000.0    125250.0
# 2              MARUTI SUZUKI SWIFT VDI DIESEL 2013   450000.0    329250.0
# 3               FORD ENDEAVOUR XLT 4X2 DIESEL 2008   600000.0    300000.0
# 4  MARUTI SUZUKI SWIFT DZIRE VDI BS IV DIESEL 2013   550000.0    429250.0
#
#        EMI  TENURE ADDRESSCONFIRMED  ... PROFESSIONTYPE  \
# 0  13369.0    36.0                Y  ...            SEP
# 1   5428.0    30.0                Y  ...            SEP
# ...

# %%
df = df.dropna()
print(df)       # we have removed all the rows with null values.
# Out:
#        UID Good_Bad CUSTOMER_PROFILE_CODE   LOCATIONNAME  \
# 0        1      Bad               PROF270        MADURAI
# 1        2     Good               PROF218        KOLKATA
# 2        3     Good               PROF305         NAGPUR
# 6        7     Good               PROF324     CHANDIGARH
# 8        9      Bad               PROF285           ROWB
# ...    ...      ...                   ...            ...
# 9994  9995      Bad               PROF289      HYDERABAD
# 9995  9996      Bad               PROF245        BIKANER
# 9996  9997      Bad               PROF096  VISAKHAPATNAM
# 9997  9998     Good               PROF358         ORISSA
# 9998  9999      Bad               PROF372         SALEM
#
#                                 VEHICLEMODEL  ASSETCOST  LOANAMOUNT      EMI  \
# 0             HONDA CITY 1.5 GXI PETROL 2008   900000.0    350000.0  13369.0
# 1       MARUTI SUZUKI EECO 7 STR PETROL 2011   400000.0    125250.0   5428.0
# ...

# %%
df.shape
# Out:
# (6430, 45)

# %%
dfcat = df.select_dtypes(include=['object']).copy()
dfcat     # a new dataframe for the columns with categorical data.
# Out:
#      Good_Bad CUSTOMER_PROFILE_CODE   LOCATIONNAME  \
# 0         Bad               PROF270        MADURAI
# 1        Good               PROF218        KOLKATA
# 2        Good               PROF305         NAGPUR
# 6        Good               PROF324     CHANDIGARH
# 8         Bad               PROF285           ROWB
# ...       ...                   ...            ...
# 9994      Bad               PROF289      HYDERABAD
# 9995      Bad               PROF245        BIKANER
# 9996      Bad               PROF096  VISAKHAPATNAM
# 9997     Good               PROF358         ORISSA
# 9998      Bad               PROF372         SALEM
#
#                                 VEHICLEMODEL ADDRESSCONFIRMED  \
# 0             HONDA CITY 1.5 GXI PETROL 2008                Y
# 1       MARUTI SUZUKI EECO 7 STR PETROL 2011                Y
# 2        MARUTI SUZUKI SWIFT VDI DIESEL 2013                Y
# 6     TOYOTA INNOVA 2.5 G4 7 STR DIESEL 2011                Y
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

dfcat1 = dfcat.apply(le.fit_transform)
dfcat1         # lebel encoding the categorical data.
# Out:
#       Good_Bad  CUSTOMER_PROFILE_CODE  LOCATIONNAME  VEHICLEMODEL  \
# 0            0                    110            46           278
# 1            1                     65            41          1111
# 2            1                    137            48          1363
# 6            1                    153            15          1982
# 8            0                    124            56           337
# ...        ...                    ...           ...           ...
# 9994         0                    127            28          1018
# 9995         0                     87            13           893
# 9996         0                     26            68          1537
# 9997         1                    178            50          1058
# 9998         0                    191            58           913
#
#       ADDRESSCONFIRMED  DESIGNATION  RESIDENCETYPE  BUSINESSCATEGORY  \
# 0                    1           44              2                 4
# ...

# %%
df1 = df.select_dtypes(include=['object'])
df1
# Out:
#      Good_Bad CUSTOMER_PROFILE_CODE   LOCATIONNAME  \
# 0         Bad               PROF270        MADURAI
# 1        Good               PROF218        KOLKATA
# 2        Good               PROF305         NAGPUR
# 6        Good               PROF324     CHANDIGARH
# 8         Bad               PROF285           ROWB
# ...       ...                   ...            ...
# 9994      Bad               PROF289      HYDERABAD
# 9995      Bad               PROF245        BIKANER
# 9996      Bad               PROF096  VISAKHAPATNAM
# 9997     Good               PROF358         ORISSA
# 9998      Bad               PROF372         SALEM
#
#                                 VEHICLEMODEL ADDRESSCONFIRMED  \
# 0             HONDA CITY 1.5 GXI PETROL 2008                Y
# 1       MARUTI SUZUKI EECO 7 STR PETROL 2011                Y
# 2        MARUTI SUZUKI SWIFT VDI DIESEL 2013                Y
# 6     TOYOTA INNOVA 2.5 G4 7 STR DIESEL 2011                Y
# ...

# %%
a = df1.columns
a
# Out:
# Index(['Good_Bad', 'CUSTOMER_PROFILE_CODE', 'LOCATIONNAME', 'VEHICLEMODEL',
#        'ADDRESSCONFIRMED', 'DESIGNATION', 'RESIDENCETYPE', 'BUSINESSCATEGORY',
#        'STABILITYCONFIRMED', 'ISFAMILYINVOLVED', 'OFFICETYPE',
#        'BUSINESSMARGINNET', 'NOOFEMPLOYEES', 'NAMEBOARDSEEN', 'OFFICELOCALITY',
#        'ISRESIDENCECOMEOFFICE', 'ENDUSEOFLOAN', 'ASSETLOCATION',
#        'NEIGHBOURREF', 'POLITICALLINK', 'PROFESSIONTYPE',
#        'APPLICANTDESIGNATION', 'IMGCONFIRM', 'FOIR'],
#       dtype='object')

# %%
type(a)
# Out:
# pandas.core.indexes.base.Index

# %%
df3 = df.drop(labels = a, axis = 1)
df3
# Out:
#        UID  ASSETCOST  LOANAMOUNT      EMI  TENURE  NOOFYEARSINSAMECITY  \
# 0        1   900000.0    350000.0  13369.0    36.0                 20.0
# 1        2   400000.0    125250.0   5428.0    30.0                 45.0
# 2        3   450000.0    329250.0   8536.0    60.0                 15.0
# 6        7   280000.0    234250.0  11809.0    24.0                 42.0
# 8        9   225000.0    184250.0   4837.0    60.0                 35.0
# ...    ...        ...         ...      ...     ...                  ...
# 9994  9995   160000.0    110000.0   5612.0    24.0                  5.0
# 9995  9996   750000.0    700000.0  18084.0    60.0                 20.0
# 9996  9997   500000.0    404250.0  16283.0    36.0                 20.0
# 9997  9998   300000.0    154250.0   4435.0    48.0                 17.0
# 9998  9999  1400000.0    808500.0  23413.0    48.0                 50.0
#
#       RESIDENCESTABILITY  RESIDENCELOCALITY  BUSINESSMARGINGROSS  \
# ...

# %%
df3.shape
# Out:
# (6430, 21)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(dfcat1)
# Out:
# pandas.core.frame.DataFrame

# %%
df4 = pd.concat([df3, dfcat1], axis = 1 )
df4
# Out:
#        UID  ASSETCOST  LOANAMOUNT      EMI  TENURE  NOOFYEARSINSAMECITY  \
# 0        1   900000.0    350000.0  13369.0    36.0                 20.0
# 1        2   400000.0    125250.0   5428.0    30.0                 45.0
# 2        3   450000.0    329250.0   8536.0    60.0                 15.0
# 6        7   280000.0    234250.0  11809.0    24.0                 42.0
# 8        9   225000.0    184250.0   4837.0    60.0                 35.0
# ...    ...        ...         ...      ...     ...                  ...
# 9994  9995   160000.0    110000.0   5612.0    24.0                  5.0
# 9995  9996   750000.0    700000.0  18084.0    60.0                 20.0
# 9996  9997   500000.0    404250.0  16283.0    36.0                 20.0
# 9997  9998   300000.0    154250.0   4435.0    48.0                 17.0
# 9998  9999  1400000.0    808500.0  23413.0    48.0                 50.0
#
#       RESIDENCESTABILITY  RESIDENCELOCALITY  BUSINESSMARGINGROSS  \
# ...

# %%
df4.describe
# Out:
# <bound method NDFrame.describe of        UID  ASSETCOST  LOANAMOUNT      EMI  TENURE  NOOFYEARSINSAMECITY  \
# 0        1   900000.0    350000.0  13369.0    36.0                 20.0
# 1        2   400000.0    125250.0   5428.0    30.0                 45.0
# 2        3   450000.0    329250.0   8536.0    60.0                 15.0
# 6        7   280000.0    234250.0  11809.0    24.0                 42.0
# 8        9   225000.0    184250.0   4837.0    60.0                 35.0
# ...    ...        ...         ...      ...     ...                  ...
# 9994  9995   160000.0    110000.0   5612.0    24.0                  5.0
# 9995  9996   750000.0    700000.0  18084.0    60.0                 20.0
# 9996  9997   500000.0    404250.0  16283.0    36.0                 20.0
# 9997  9998   300000.0    154250.0   4435.0    48.0                 17.0
# 9998  9999  1400000.0    808500.0  23413.0    48.0                 50.0
#
#       RESIDENCESTABILITY  RESIDENCELOCALITY  BUSINESSMARGINGROSS  \
# ...

# %%
d = df4['Good_Bad']
d
# Out:
# 0       0
# 1       1
# 2       1
# 6       1
# 8       0
#        ..
# 9994    0
# 9995    0
# 9996    0
# 9997    1
# 9998    0
# Name: Good_Bad, Length: 6430, dtype: int32

# %%
data = df4.drop(['Good_Bad'], axis = 1)

# %%
data1 = pd.concat([d, data], axis = 1)

# %%
data1
# Out:
#       Good_Bad   UID  ASSETCOST  LOANAMOUNT      EMI  TENURE  \
# 0            0     1   900000.0    350000.0  13369.0    36.0
# 1            1     2   400000.0    125250.0   5428.0    30.0
# 2            1     3   450000.0    329250.0   8536.0    60.0
# 6            1     7   280000.0    234250.0  11809.0    24.0
# 8            0     9   225000.0    184250.0   4837.0    60.0
# ...        ...   ...        ...         ...      ...     ...
# 9994         0  9995   160000.0    110000.0   5612.0    24.0
# 9995         0  9996   750000.0    700000.0  18084.0    60.0
# 9996         0  9997   500000.0    404250.0  16283.0    36.0
# 9997         1  9998   300000.0    154250.0   4435.0    48.0
# 9998         0  9999  1400000.0    808500.0  23413.0    48.0
#
#       NOOFYEARSINSAMECITY  RESIDENCESTABILITY  RESIDENCELOCALITY  \
# 0                    20.0                 4.0                3.0
# 1                    45.0                45.0                3.0
# ...

# %%
x = data1.iloc[:,1:]
x
# Out:
#        UID  ASSETCOST  LOANAMOUNT      EMI  TENURE  NOOFYEARSINSAMECITY  \
# 0        1   900000.0    350000.0  13369.0    36.0                 20.0
# 1        2   400000.0    125250.0   5428.0    30.0                 45.0
# 2        3   450000.0    329250.0   8536.0    60.0                 15.0
# 6        7   280000.0    234250.0  11809.0    24.0                 42.0
# 8        9   225000.0    184250.0   4837.0    60.0                 35.0
# ...    ...        ...         ...      ...     ...                  ...
# 9994  9995   160000.0    110000.0   5612.0    24.0                  5.0
# 9995  9996   750000.0    700000.0  18084.0    60.0                 20.0
# 9996  9997   500000.0    404250.0  16283.0    36.0                 20.0
# 9997  9998   300000.0    154250.0   4435.0    48.0                 17.0
# 9998  9999  1400000.0    808500.0  23413.0    48.0                 50.0
#
#       RESIDENCESTABILITY  RESIDENCELOCALITY  BUSINESSMARGINGROSS  \
# ...

# %%
y = data1.iloc[:,:1]
y
# Out:
#       Good_Bad
# 0            0
# 1            1
# 2            1
# 6            1
# 8            0
# ...        ...
# 9994         0
# 9995         0
# 9996         0
# 9997         1
# 9998         0
#
# [6430 rows x 1 columns]

# %% [markdown]
# ##  We are done with data preprocessing

# %% [markdown]
# ## Now we will start Feature Engineering

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=10)
pca.fit(x)

principalComponents = pca.transform(x)
principalDf = pd.DataFrame(data = principalComponents)

# %%
principalDf    # feature engineered columns
# Out:
#                   0              1             2              3  \
# 0    -332214.676812    1683.612694  2.088223e+05 -215864.959484
# 1    -338948.230072    4655.233913 -2.240980e+05  106065.785210
# 2    -295059.210168  -23735.745755 -8.939145e+04   14405.163793
# 3     252123.805814  812701.557635 -2.161119e+05  165938.334566
# 4    -222451.661405   47481.136363 -2.955773e+05  186451.767673
# ...             ...            ...           ...            ...
# 6425 -340941.965475    5359.624372 -3.589140e+05  258030.104232
# 6426 -331598.000320    1655.368443  2.639242e+05 -283980.800341
# 6427 -335163.645134    2788.179973  1.356654e+04    -223.966948
# 6428 -117531.189629  -21329.769163 -2.676868e+05  156064.652526
# 6429 -317591.078222   -6584.893159  1.096599e+06 -248841.358367
#
#                   4              5            6            7           8  \
# 0     -41670.436757  249261.557100  5340.243971  1476.797254   -9.086774
# ...

# %%
from sklearn.ensemble import RandomForestRegressor

regressor = RandomForestRegressor(n_estimators=20, random_state=0)
regressor.fit(x, y)
# Out:
# c:\users\kabir\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=20,
#                       n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                       warm_start=False)

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
 
lr = LinearRegression()

rfe = RFE(lr, n_features_to_select=10)
rfe.fit(x_train,y_train)
# Out:
# c:\users\kabir\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# RFE(estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                normalize=False),
#     n_features_to_select=10, step=1, verbose=0)

# %%
s = rfe.support_   # We will take column with where it gives true
s
# Out:
# array([False, False, False, False, False, False, False,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False,  True,
#        False,  True,  True, False, False, False, False,  True,  True,
#        False, False,  True,  True, False, False,  True, False])

# %%
rfe.ranking_          # these are the ranking of columns of the given dataset which we should take in the consideration rank wise.
# Out:
# array([23, 26, 30, 25,  8, 15, 18,  1, 10, 29, 20,  7, 32, 31,  2,  6, 33,
#        35, 34, 27, 28, 14, 12, 22,  1, 19,  1,  3,  1,  1,  4,  5, 11, 13,
#         1,  1, 21, 17,  1,  1,  9, 24,  1, 16])
